# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글성정 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Win용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용

# %% [markdown]
# 다중막대그래프 - 옆으로 여러개 막대그래프

# %%
### 남자인구현황 그래프 출력하시오.
df = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,usecols='B,E:Y',nrows=1,index_col='행정기관')
df

### 여자인구현황 그래프 출력하시오.
### B,AB:AV
df2 = pd.read_excel('연령별인구현황_202410.xlsx',skiprows=3,usecols='B,AB:AV',nrows=1,index_col='행정기관')

# %%
## row행을 출력
# df.loc['전국  '][0]
# df.iloc[0][0]
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
## 1. 데이터값 ,천단위 표시 제거, int타입 변경
## df.loc['전국  ']
## df.iloc[0]
# df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)
## 1. 데이터값 ,천단위 표시 제거, int타입 변경
## df2.loc['전국  ']
## df2.iloc[0]
# df2.iloc[0] = df2.iloc[0].str.replace(",","").astype(int)

# %%
### 남자컬럼, 여자컬럼을 복사
# df2.columns = df.columns
df2.columns

# %%
df2.iloc[0] = df2.iloc[0].str.replace(",","").astype(int)

# %%
plt.barh(df2.columns,df2.iloc[0]//1000)
plt.title('2024년 인구현황')
plt.ylabel('연령대')
plt.xlabel('인구수')

# %%
# 연령별 막대그래프로 출력하시오
## 2. plt.bar(x,y) 출력
plt.barh(df.columns,-df.iloc[0]//1000,label='남자')
plt.barh(df2.columns,df2.iloc[0]//1000,label='여자')
plt.title('2024년 인구현황')
plt.ylabel('연령대')
plt.xlabel('인구수')
plt.legend()

# %%
w = 0.25
plt.bar(index,df['국어'],width=w,label='국어')
plt.bar(index-0.25,df['영어'],width=w,label='영어')
plt.bar(index+0.25,df['수학'],width=w,label='수학')
plt.xticks(index)
plt.ylim(0,120)

## for 값을 그래프에 출력
for i in range(len(index)):
  plt.text(i,df['국어'][i]+1,df['국어'][i],ha='center')
  plt.text(i-w,df['영어'][i]+1,df['영어'][i],ha='center')
  plt.text(i+w,df['수학'][i]+1,df['수학'][i],ha='center')

plt.legend(ncol=3,loc='upper center')
plt.show()
