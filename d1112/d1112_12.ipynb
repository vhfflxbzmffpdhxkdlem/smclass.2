# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글성정 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Win용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용

# %% [markdown]
# * drinks.csv파일 불러와서
# * total_servings 컬럼을 모든 serving 합계
# * beer_servings,spirit_servings,wine_servings
# * country 별 막대그래프를 생성하시오.

# %%
df = pd.read_csv('drinks.csv')
df['total_servings'] = df['beer_servings']+df['spirit_servings']+df['wine_servings']
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings
# 0                             0.0        AS               0
# 1                             4.9        EU             275
# ...

# %%
plt.bar(df['country'],df['total_servings'])
  if i == 138:
    plt.bar(df['country'],df['total_servings'].color='r')
for i in range(192):

  plt.text(df['country'][i],df['total_servings'][i],df['total_servings'][i])

plt.show()
# Out:
#   Cell In[16], line 2
#     if i == 138:
#     ^
# IndentationError: unexpected indent

# %%
df[df['country'].str.lower().str.contains('kor')]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 46   North Korea              0                0              0
# 138  South Korea            140               16              9
#
#      total_litres_of_pure_alcohol continent  total_servings
# 46                            0.0        AS               0
# 138                           9.8        AS             165
