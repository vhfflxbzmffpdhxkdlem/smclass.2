# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글성정 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Win용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용

df=pd.read_excel('score.xlsx',index_col='지원번호')

# %%
df['학년'] = [3,3,2,1,1,3,2,2]

# %%
## 산점도그래프
# sizes = np.random.rand(8)*1000
sizes = df['학년']*500
plt.title('산점도 그래프')
plt.xlabel('영어')
plt.ylabel('수학')
# s: 산점도 크기 변경, c = 산점도 표시컬럼
## s : 산점도 크기 변경, c = 산점도 표시 컬럼내용 색상
## cmap : 색상표사용,
plt.scatter(df['영어'],df['수학'],sizes=sizes,c=df['학년'],cmap='plasma',alpha=0.5)
## colorbar : 생상바 생성 - 삼전도색상의 학년표시
## ticks 바범위, shrink : 바크기, orientation : 하단배치, 옆배치
plt.colorbar(ticks=[1,2,3],label='학년',shrink=0.5,orientation='horizontal')
plt.legend()
plt.show()
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_8428\87763307.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
