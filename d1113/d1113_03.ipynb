# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글성정 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Win용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용

# %%
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
# 원그래프
# values = [30,25,20,13,10,2]   # 100퍼센트
values = [1,2,1,1,1,1]
explode = [0.1,0.1,0,0,0,0]
labels = ['python','java','javascript','oracle','html','etc']
colors = ['plum','beige','skyblue','bisque','khaki','peachpuff']
plt.title('프로그램 사용률')
## pie함수(데이터값), labels: 글자출력
## explode : 원그래프 분리,  countclock : 시계반대방향, False : 시계방향
## startangle = 90 : 12시부터 시작됨.
## 데이터 값 출력 : atuopct
## colors : 색상변경
plt.pie(values,labels=labels,colors=colors,explode=explode,autopct='%.1f%%',counterclock=False,startangle=90)
# plt.legend(loc='upper right')
plt.legend(loc=(1.1,0.2),title='언어별 선호도')
plt.show()
