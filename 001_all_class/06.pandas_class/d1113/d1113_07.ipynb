# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글성정 
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Win용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용

# %%
data = {
   '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
   '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
   '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
   '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)

# %%
df['관객 수'][8]
# Out:
# np.float64(1425.5)

# %%
s_bar = plt.bar(df['영화'],df['관객 수'])
plt.plot(df['영화'],df['관객 수'][8]*9,ls='--',color='black')

plt.text(df['영화'][0],df['관객 수'][0],int(df['관객 수']),ha='center')
plt.xticks(rotation=90)
plt.ylim(1000,1800)
s_bar[len(df.index)-1].set_color('red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\python\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 8 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 s_bar = plt.bar(df['영화'],df['관객 수'])
# ----> 2 plt.plot(df['영화'],df['관객 수'][8]*9,ls='--',color='black')
#       4 plt.text(df['영화'][0],df['관객 수'][0],int(df['관객 수']),ha='center')
#       5 plt.xticks(rotation=90)
#
# File c:\python\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\python\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\python\Lib\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 8

# %%
### 영화 관객수를 막대그래프로 출력하시오.
plt.xlim = (12.5)
plt.ylim = (1000,1800)
plt.figure(figsize=(15,5)) 
plt.bar(df['영화'],df['관객 수'])[len(df['영화'])-1].set_color('red')
### 평균 막대그래프를 추가하고, 평균 선을 그어서... 표시하시오.
plt.plot(df['영화'],[df['관객 수'].mean()]*9,ls=':',color='red')
## 이름 : 평균, 년도 2024 관객수 : 평균관객수 , 평점 : 평균평점
## row 1개를 추가하시오.
df.loc[8] = ['평균',2024,df['관객 수'].mean(),df['평점'].mean()]
